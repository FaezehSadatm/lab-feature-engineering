# %%
import pandas as pd
import numpy as np
import datetime
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('C:/Users/faeze/OneDrive/Desktop/Ironhack/Unit-7/Session-41/data_7.01_activities/files_for_activities/learningSet.csv')
data
# Out:
#        ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0         8901     GRI      0    IL  61081                    3712      0
# 1         9401     BOA      1    CA  91326                    5202      0
# 2         9001     AMH      1    NC  27017                       0      0
# 3         8701     BRY      0    CA  95953                    2801      0
# 4         8601              0    FL  33176                    2001      0
# ...        ...     ...    ...   ...    ...      ...      ...   ...    ...
# 95407     9601     ASE      1    AK  99504                       0      0
# 95408     9601     DCD      1    TX  77379                    5001      0
# 95409     9501     MBC      1    MI  48910                    3801      0
# 95410     8601     PRV      0    CA  91320                    4005      0
# 95411     8801     MCC      2    NC  28409                    1801      0
#
#       RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R  MDMAUD_F  \
# ...

# %%
data.shape
# Out:
# (95412, 481)

# %%
data.columns = [col_name.upper().replace(' ', '_').replace('/', '') for col_name in data.columns]
data.columns
# Out:
# Index(['ODATEDW', 'OSOURCE', 'TCODE', 'STATE', 'ZIP', 'MAILCODE', 'PVASTATE',
#        'DOB', 'NOEXCH', 'RECINHSE',
#        ...
#        'TARGET_D', 'HPHONE_D', 'RFA_2R', 'RFA_2F', 'RFA_2A', 'MDMAUD_R',
#        'MDMAUD_F', 'MDMAUD_A', 'CLUSTER2', 'GEOCODE2'],
#       dtype='object', length=481)

# %%
data.describe()
# Out:
#             ODATEDW         TCODE           DOB           AGE       NUMCHLD  \
# count  95412.000000  95412.000000  95412.000000  71747.000000  12386.000000
# mean    9141.363256     54.223117   2723.602933     61.611649      1.527773
# std      343.454752    953.844476   2132.241295     16.664199      0.806861
# min     8306.000000      0.000000      0.000000      1.000000      1.000000
# 25%     8801.000000      0.000000    201.000000     48.000000      1.000000
# 50%     9201.000000      1.000000   2610.000000     62.000000      1.000000
# 75%     9501.000000      2.000000   4601.000000     75.000000      2.000000
# max     9701.000000  72002.000000   9710.000000     98.000000      7.000000
#
#              INCOME       WEALTH1           HIT       MBCRAFT      MBGARDEN  \
# count  74126.000000  50680.000000  95412.000000  42558.000000  42558.000000
# mean       3.886248      5.345699      3.321438      0.152075      0.059166
# ...

# %%
dfcat = data.select_dtypes('object')
dfcat
# Out:
#       OSOURCE STATE    ZIP MAILCODE PVASTATE NOEXCH RECINHSE RECP3 RECPGVG  \
# 0         GRI    IL  61081                        0
# 1         BOA    CA  91326                        0
# 2         AMH    NC  27017                        0
# 3         BRY    CA  95953                        0
# 4                FL  33176                        0        X     X
# ...       ...   ...    ...      ...      ...    ...      ...   ...     ...
# 95407     ASE    AK  99504                        0
# 95408     DCD    TX  77379                        0
# 95409     MBC    MI  48910                        0              X
# 95410     PRV    CA  91320                        0        X
# 95411     MCC    NC  28409                        0        X             X
#
#       RECSWEEP  ... RFA_21 RFA_22 RFA_23 RFA_24 RFA_2R RFA_2A MDMAUD_R  \
# 0               ...    S4E    S4E    S4E    S4E      L      E        X
# 1               ...    N1E    N1E           F1E      L      G        X
# ...

# %%
dfnum = data.select_dtypes('number')
dfnum
# Out:
#        ODATEDW  TCODE   DOB   AGE  NUMCHLD  INCOME  WEALTH1  HIT  MBCRAFT  \
# 0         8901      0  3712  60.0      NaN     NaN      NaN    0      NaN
# 1         9401      1  5202  46.0      1.0     6.0      9.0   16      0.0
# 2         9001      1     0   NaN      NaN     3.0      1.0    2      0.0
# 3         8701      0  2801  70.0      NaN     1.0      4.0    2      0.0
# 4         8601      0  2001  78.0      1.0     3.0      2.0   60      1.0
# ...        ...    ...   ...   ...      ...     ...      ...  ...      ...
# 95407     9601      1     0   NaN      NaN     NaN      NaN    0      NaN
# 95408     9601      1  5001  48.0      1.0     7.0      9.0    1      0.0
# 95409     9501      1  3801  60.0      NaN     NaN      NaN    0      NaN
# 95410     8601      0  4005  58.0      NaN     7.0      NaN    0      NaN
# 95411     8801      2  1801  80.0      NaN     5.0      8.0    3      0.0
#
#        MBGARDEN  ...  FISTDATE  NEXTDATE  TIMELAG    AVGGIFT  CONTROLN  \
# ...

# %% [markdown]
# ### Lab | Revisiting Machine Learning Case Study

# %% [markdown]
# #### 1. Check for null values in all the columns

# %%
nulls = pd.DataFrame(data.isna().sum()*100/len(data), columns=['percentage'])
nulls.sort_values('percentage', ascending = False).head(30)
# Out:
#           percentage
# RDATE_5    99.990567
# RAMNT_5    99.990567
# RDATE_3    99.746363
# RAMNT_3    99.746363
# RDATE_4    99.705488
# RAMNT_4    99.705488
# RAMNT_6    99.186685
# RDATE_6    99.186685
# RAMNT_15   92.388798
# RDATE_15   92.388798
# RDATE_23   91.763091
# RAMNT_23   91.763091
# RDATE_20   91.732696
# RAMNT_20   91.732696
# RAMNT_7    90.677273
# RDATE_7    90.677273
# RAMNT_17   90.146942
# RDATE_17   90.146942
# RDATE_21   90.029556
# RAMNT_21   90.029556
# RAMNT_10   89.035970
# RDATE_10   89.035970
# RDATE_13   87.160944
# RAMNT_13   87.160944
# NUMCHLD    87.018404
# RDATE_11   84.551209
# RAMNT_11   84.551209
# RDATE_19   83.359535
# RAMNT_19   83.359535
# RAMNT_9    82.461326

# %% [markdown]
# #### 2. Exclude the following variables by looking at the definitions. Create a new empty list called drop_list. We will append this list and then drop all the columns in this list later:
#
#  ###### OSOURCE - symbol definitions not provided, too many categories
#  ###### ZIP CODE - we are including state already

# %%
drop_list = []
drop_list.extend(['drop_list', 'ZIP_CODE'])
drop_list
# Out:
# ['drop_list', 'ZIP_CODE']

# %% [markdown]
# #### 3. Identify columns that over 85% missing values

# %%
most_missing_value_cols = list(nulls[nulls['percentage'] > 85].index)
most_missing_value_cols
# Out:
# ['NUMCHLD',
#  'RDATE_3',
#  'RDATE_4',
#  'RDATE_5',
#  'RDATE_6',
#  'RDATE_7',
#  'RDATE_10',
#  'RDATE_13',
#  'RDATE_15',
#  'RDATE_17',
#  'RDATE_20',
#  'RDATE_21',
#  'RDATE_23',
#  'RAMNT_3',
#  'RAMNT_4',
#  'RAMNT_5',
#  'RAMNT_6',
#  'RAMNT_7',
#  'RAMNT_10',
#  'RAMNT_13',
#  'RAMNT_15',
#  'RAMNT_17',
#  'RAMNT_20',
#  'RAMNT_21',
#  'RAMNT_23']

# %% [markdown]
# #### 4. Remove those columns from the dataframe

# %%
drop_list.extend(most_missing_value_cols)
drop_list
# Out:
# ['drop_list',
#  'ZIP_CODE',
#  'NUMCHLD',
#  'RDATE_3',
#  'RDATE_4',
#  'RDATE_5',
#  'RDATE_6',
#  'RDATE_7',
#  'RDATE_10',
#  'RDATE_13',
#  'RDATE_15',
#  'RDATE_17',
#  'RDATE_20',
#  'RDATE_21',
#  'RDATE_23',
#  'RAMNT_3',
#  'RAMNT_4',
#  'RAMNT_5',
#  'RAMNT_6',
#  'RAMNT_7',
#  'RAMNT_10',
#  'RAMNT_13',
#  'RAMNT_15',
#  'RAMNT_17',
#  'RAMNT_20',
#  'RAMNT_21',
#  'RAMNT_23']

# %% [markdown]
# #### 5. Reduce the number of categories in the column GENDER. The column should only have either "M" for males, "F" for females, and "other" for all the rest
#
# ##### Note that there are a few null values in the column. We will first replace those null values using the code below:

# %%
dfcat['GENDER'].value_counts()
# Out:
# F    51277
# M    39094
#       2957
# U     1715
# J      365
# C        2
# A        2
# Name: GENDER, dtype: int64

# %%
#dfcat['GENDER'] = dfcat['GENDER'].fillna('F')

# %%
dfcat['GENDER'] = dfcat['GENDER'].replace(' ', 'F')
dfcat['GENDER'].value_counts()
# Out:
# F    54234
# M    39094
# U     1715
# J      365
# C        2
# A        2
# Name: GENDER, dtype: int64

# %%
dfcat['GENDER'] = dfcat['GENDER'].apply(lambda x: x if x in ['F', 'M'] else 'Other')

dfcat['GENDER'].value_counts()
# Out:
# F        54234
# M        39094
# Other     2084
# Name: GENDER, dtype: int64

# %% [markdown]
# ### Lab | Feature engineering

# %% [markdown]
# #### 1. Check for null values in the numerical columns.

# %%
nulls = pd.DataFrame(dfnum.isna().sum()*100/len(dfnum), columns=['percentage'])
nulls.sort_values('percentage', ascending = False).head(30)
# Out:
#           percentage
# RDATE_5    99.990567
# RAMNT_5    99.990567
# RDATE_3    99.746363
# RAMNT_3    99.746363
# RDATE_4    99.705488
# RAMNT_4    99.705488
# RAMNT_6    99.186685
# RDATE_6    99.186685
# RDATE_15   92.388798
# RAMNT_15   92.388798
# RDATE_23   91.763091
# RAMNT_23   91.763091
# RAMNT_20   91.732696
# RDATE_20   91.732696
# RAMNT_7    90.677273
# RDATE_7    90.677273
# RDATE_17   90.146942
# RAMNT_17   90.146942
# RAMNT_21   90.029556
# RDATE_21   90.029556
# RDATE_10   89.035970
# RAMNT_10   89.035970
# RDATE_13   87.160944
# RAMNT_13   87.160944
# NUMCHLD    87.018404
# RAMNT_11   84.551209
# RDATE_11   84.551209
# RDATE_19   83.359535
# RAMNT_19   83.359535
# RDATE_9    82.461326

# %% [markdown]
# #### 2. Use appropriate methods to clean the columns GEOCODE2, WEALTH1, ADI, DMA,and MSA.

# %%
lst = ['WEALTH1', 'ADI', 'DMA', 'MSA']
data[lst].hist()
# Out:
# array([[<AxesSubplot:title={'center':'WEALTH1'}>,
#         <AxesSubplot:title={'center':'ADI'}>],
#        [<AxesSubplot:title={'center':'DMA'}>,
#         <AxesSubplot:title={'center':'MSA'}>]], dtype=object)

# %%
for column in lst:
    sns.distplot(data[column])
    plt.show()

# %%
nulls_lst = nulls.loc[lst]
nulls_lst
# Out:
#          percentage
# WEALTH1   46.882992
# ADI        0.138347
# DMA        0.138347
# MSA        0.138347

# %%
# ADI, DMA and MSA columns have some NaNs and I prefer to fill them with median.
# WEALTH1 column has a lot of NaNs which I prefer to use bfill method to keep it more balance.

# %%
def log_transform(x):
    if np.isfinite(x) and x!=0:
        return np.log(x)
    else:
        return np.NAN

# %%
data['ADI'] = data['ADI'].apply(log_transform).fillna(data1['ADI'].median())
data['DMA'] = data['DMA'].apply(log_transform).fillna(data1['DMA'].median())
data['MSA'] = data['MSA'].apply(log_transform).fillna(data1['MSA'].median())
data['WEALTH1'] = data['WEALTH1'].apply(log_transform).fillna(method='bfill')

# %% [markdown]
# dfnum['WEALTH1'].fillna(method='bfill', inplace=True)
# dfnum['ADI'].fillna(dfnum['ADI'].median(), inplace=True)
# dfnum['DMA'].fillna(dfnum['DMA'].median(), inplace=True)
# dfnum['MSA'].fillna(dfnum['MSA'].median(), inplace=True)

# %%
nulls = pd.DataFrame(nulls_lst.isna().sum()*100/len(nulls_lst), columns=['percentage'])
nulls.sort_values('percentage', ascending = False).head(30)
# Out:
#             percentage
# percentage         0.0

# %%
# GEOCODE2  is a categorical column so I want to merge NaN rows with most frequent category.

# %%
data['GEOCODE2'].value_counts()
# Out:
# A    34484
# B    28505
# D    16580
# C    15524
#        187
# Name: GEOCODE2, dtype: int64

# %%
data['GEOCODE2'] = data['GEOCODE2'].replace(' ', 'A')
data['GEOCODE2'].value_counts()
# Out:
# A    34671
# B    28505
# D    16580
# C    15524
# Name: GEOCODE2, dtype: int64

# %% [markdown]
# #### 3. Use appropriate EDA technique where ever necessary.

# %%
data.describe().apply(lambda x: round(x,1))
# Out:
#        ODATEDW    TCODE      DOB      AGE  NUMCHLD   INCOME  WEALTH1      HIT  \
# count  95412.0  95412.0  95412.0  71747.0  12386.0  74126.0  95412.0  95412.0
# mean    9141.4     54.2   2723.6     61.6      1.5      3.9      1.6      3.3
# std      343.5    953.8   2132.2     16.7      0.8      1.9      0.6      9.3
# min     8306.0      0.0      0.0      1.0      1.0      1.0      0.0      0.0
# 25%     8801.0      0.0    201.0     48.0      1.0      2.0      1.4      0.0
# 50%     9201.0      1.0   2610.0     62.0      1.0      4.0      1.8      0.0
# 75%     9501.0      2.0   4601.0     75.0      2.0      5.0      2.1      3.0
# max     9701.0  72002.0   9710.0     98.0      7.0      7.0      2.2    241.0
#
#        MBCRAFT  MBGARDEN  ...  FISTDATE  NEXTDATE  TIMELAG  AVGGIFT  CONTROLN  \
# count  42558.0   42558.0  ...   95412.0   85439.0  85439.0  95412.0   95412.0
# mean       0.2       0.1  ...    9135.7    9151.0      8.1     13.3   95778.2
# ...

# %%
data.corr()
# Out:
#            ODATEDW     TCODE       DOB       AGE   NUMCHLD    INCOME  \
# ODATEDW   1.000000 -0.033214  0.099450 -0.309158  0.034955  0.092271
# TCODE    -0.033214  1.000000 -0.003527  0.011079  0.003457 -0.005683
# DOB       0.099450 -0.003527  1.000000 -0.999753  0.136305  0.237440
# AGE      -0.309158  0.011079 -0.999753  1.000000 -0.191526 -0.250397
# NUMCHLD   0.034955  0.003457  0.136305 -0.191526  1.000000  0.022066
# ...            ...       ...       ...       ...       ...       ...
# TARGET_B -0.032270  0.004941 -0.001703  0.009080 -0.014959  0.018688
# TARGET_D -0.006948  0.000158  0.002754  0.002282 -0.014920  0.032063
# HPHONE_D -0.073435 -0.002025  0.076916  0.096668  0.024972 -0.029094
# RFA_2F   -0.065082  0.007835 -0.048517  0.058292  0.019857 -0.079972
# CLUSTER2 -0.060178  0.001131 -0.089878  0.057309 -0.020415 -0.375648
#
#            WEALTH1       HIT   MBCRAFT  MBGARDEN  ...  FISTDATE  NEXTDATE  \
# ...

# %%
for column in lst:
    sns.distplot(data[column])
    plt.show()

# %%
for column in lst:
    sns.boxplot(data[column])
    plt.show()
